# %%
# !pip install pandas numpy matplotlib seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %%
import pandas as pd

# Create sample dataset
data = {
    "OrderID": [101, 102, 103, 104, 104],
    "Customer": ["Aisha", "Rahul", "Priya", "Aisha", "Aisha"],
    "Product": ["Laptop", "Mouse", "Keyboard", "Laptop", "Laptop"],
    "Quantity": [1, 2, 1, 1, 1],
    "Price": [55000, 500, 1500, 55000, 55000],
    "OrderDate": ["2024-01-01", "2024-01-05", "2024-01-07", "2024-01-01", "2024-01-01"]
}

df = pd.DataFrame(data)
df
# Out:
#    OrderID Customer   Product  Quantity  Price   OrderDate
# 0      101    Aisha    Laptop         1  55000  2024-01-01
# 1      102    Rahul     Mouse         2    500  2024-01-05
# 2      103    Priya  Keyboard         1   1500  2024-01-07
# 3      104    Aisha    Laptop         1  55000  2024-01-01
# 4      104    Aisha    Laptop         1  55000  2024-01-01

# %%
df["TotalAmount"] = df["Quantity"] * df["Price"]

# %%
df["OrderDate"] = pd.to_datetime(df["OrderDate"])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   OrderID      5 non-null      int64
#  1   Customer     5 non-null      object
#  2   Product      5 non-null      object
#  3   Quantity     5 non-null      int64
#  4   Price        5 non-null      int64
#  5   OrderDate    5 non-null      datetime64[ns]
#  6   TotalAmount  5 non-null      int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 412.0+ bytes

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.isnull().sum()
df.duplicated().sum()
# Out:
# np.int64(1)
